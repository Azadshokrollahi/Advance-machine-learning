# %% [markdown]
# <a href="https://colab.research.google.com/github/aeau/MAU-AML-labs/blob/develop/0-basics_intro/1-datasets_dataloaders-colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Datasets and Dataloaders #
#
# https://pytorch.org/docs/stable/data.html#iterable-style-datasets
#
# Dataset stores the samples and their corresponding labels, and DataLoader wraps an iterable around the Dataset to enable easy access to the samples.
#
# Pre-loaded datasets from pytorch:
# - Image datasets: https://pytorch.org/vision/stable/datasets.html
# - Text datasets: https://pytorch.org/text/stable/datasets.html
# - Audio datasets: https://pytorch.org/text/stable/datasets.html

# %%
import torch
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor, Lambda, Grayscale, Compose, Resize
import matplotlib.pyplot as plt

# %% [markdown]
# We load the FashionMNIST Dataset with the following parameters:
#
# - root is the path where the train/test data is stored,
# - train specifies training or test dataset,
# - download=True downloads the data from the internet if it’s not available at root.
# - transform and target_transform specify the feature and label transformations

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Change root dir to wherever your data is! 
root_dir = '/content/drive/MyDrive/Work/PHD/courses-AML/data_aml'
data_path = "/content/data"
# !unzip "/content/drive/MyDrive/Work/PHD/courses-AML/data_aml/FashionMNIST.zip" -d $data_path

training_data = datasets.FashionMNIST(
    root=data_path,
    train=True,
    download=True,
    transform=ToTensor()
)

test_data = datasets.FashionMNIST(
    root=data_path,
    train=False,
    download=True,
    transform=ToTensor()
)
# Out:
# Archive:  /content/drive/MyDrive/Work/PHD/courses-AML/data_aml/FashionMNIST.zip
#    creating: /content/data/FashionMNIST/
#   inflating: /content/data/FashionMNIST/.DS_Store
#   inflating: /content/data/__MACOSX/FashionMNIST/._.DS_Store
#    creating: /content/data/FashionMNIST/processed/
#    creating: /content/data/FashionMNIST/raw/
#   inflating: /content/data/FashionMNIST/processed/training.pt
#   inflating: /content/data/FashionMNIST/processed/test.pt
#   inflating: /content/data/FashionMNIST/raw/t10k-images-idx3-ubyte
#   inflating: /content/data/FashionMNIST/raw/t10k-labels-idx1-ubyte
#   inflating: /content/data/FashionMNIST/raw/train-images-idx3-ubyte
#   inflating: /content/data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
#   inflating: /content/data/FashionMNIST/raw/train-images-idx3-ubyte.gz
#   inflating: /content/data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
#   inflating: /content/data/FashionMNIST/raw/train-labels-idx1-ubyte
#   inflating: /content/data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# ## Iterating datastes ##
#
# We can index Datasets manually like a list: training_data[index]. We use matplotlib to visualize some samples in our training data.

# %%
# We use this dictionary to connect the indices to string
labels_map = {
    0: "T-Shirt",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle Boot",
}

figure = plt.figure(figsize=(8, 8))
cols, rows = 3, 3
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(training_data), size=(1,)).item() # Get rnd_id
    img, label = training_data[sample_idx] # index dataset (gets you the img and label - index)
    figure.add_subplot(rows, cols, i)
    plt.title(labels_map[label])
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()

# %% [markdown]
# ## Creating a Custom Dataset for your files ##
# A custom Dataset class must implement three functions: __init__, __len__, and __getitem__. Take a look at this implementation; the FashionMNIST images are stored in a directory img_dir, and their labels are stored separately in a CSV file annotations_file.

# %%
import os
import pandas as pd
from torchvision.io import read_image

class CustomImageDataset(Dataset):
    def __init__(self, annotations_file, img_dir, transform=None, target_transform=None):
        self.img_labels = pd.read_csv(annotations_file)
        self.img_dir = img_dir
        self.transform = transform
        self.target_transform = target_transform

    def __len__(self):
        return len(self.img_labels)

    def __getitem__(self, idx):
        img_path = os.path.join(self.img_dir, self.img_labels.iloc[idx, 0])
        image = read_image(img_path) # Converts to tensor
        label = self.img_labels.iloc[idx, 1]
        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = self.target_transform(label)
        sample = {"image": image, "label": label}
        return sample

# %% [markdown]
# ### We have another dataset, how do we load it with this custom dataset? ###

# %%
# create the annotation file

from os import listdir
from os.path import isfile, join
import csv

#Remember to change this to your particular path! 
data_path = "/content/data"
edd_train_data = "/content/data/EDD-dataset/train"
edd_train_data_csv = "/content/data/EDD-dataset/train/train.csv"
edd_test_data = "/content/data/EDD-dataset/test"
edd_test_data_csv = "/content/data/EDD-dataset/test/test.csv"
# !unzip "/content/drive/MyDrive/Work/PHD/courses-AML/data_aml/EDD-dataset.zip" -d $data_path


with open(edd_train_data_csv, 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['image_location', 'label']) # Write header
    for dirs in listdir(edd_train_data):
#         print(dirs)
        if(dirs.endswith(".csv") or dirs.endswith('.DS_Store')):
            continue
        for f in listdir(join(edd_train_data, dirs)):
            if(join(edd_train_data, dirs, f).endswith(".csv")):
                continue
            elif isfile(join(edd_train_data, dirs, f)):
                writer.writerow([join(dirs, f), dirs])
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/data/EDD-dataset/train/0/2484.png
#   inflating: /content/data/EDD-dataset/train/0/6184.png
#   inflating: /content/data/EDD-dataset/train/0/2480.png
#   inflating: /content/data/EDD-dataset/train/0/6194.png
#   inflating: /content/data/EDD-dataset/train/0/7261.png
#   inflating: /content/data/EDD-dataset/train/0/8152.png
#   inflating: /content/data/EDD-dataset/train/0/7507.png
#   inflating: /content/data/EDD-dataset/train/0/7513.png
#   inflating: /content/data/EDD-dataset/train/0/5462.png
#   inflating: /content/data/EDD-dataset/train/0/8146.png
#   inflating: /content/data/EDD-dataset/train/0/6143.png
#   inflating: /content/data/EDD-dataset/train/0/2457.png
#   inflating: /content/data/EDD-dataset/train/0/5338.png
#   inflating: /content/data/EDD-dataset/train/0/6157.png
#   inflating: /content/data/EDD-dataset/train/0/4998.png
#   inflating: /content/data/EDD-dataset/train/0/2866.png
#   inflating: /content/data/EDD-dataset/train/0/2872.png
#   inflating: /content/data/EDD-dataset/train/0/7936.png
#   inflating: /content/data/EDD-dataset/train/0/7705.png
#   inflating: /content/data/EDD-dataset/train/0/3563.png
#   inflating: /content/data/EDD-dataset/train/0/6369.png
#   inflating: /content/data/EDD-dataset/train/0/5660.png
#   inflating: /content/data/EDD-dataset/train/0/2669.png
#   inflating: /content/data/EDD-dataset/train/0/6341.png
#   inflating: /content/data/EDD-dataset/train/0/5648.png
#   inflating: /content/data/EDD-dataset/train/0/4542.png
#   inflating: /content/data/EDD-dataset/train/0/2.png
#   inflating: /content/data/EDD-dataset/train/0/6433.png
#   inflating: /content/data/EDD-dataset/train/0/5099.png
#   inflating: /content/data/EDD-dataset/train/0/5927.png
#   inflating: /content/data/EDD-dataset/train/0/7842.png
#   inflating: /content/data/EDD-dataset/train/0/6209.png
#   inflating: /content/data/EDD-dataset/train/0/7665.png
#   inflating: /content/data/EDD-dataset/train/0/6553.png
#   inflating: /content/data/EDD-dataset/train/0/7895.png
#   inflating: /content/data/EDD-dataset/train/0/6235.png
#   inflating: /content/data/EDD-dataset/train/0/4422.png
#   inflating: /content/data/EDD-dataset/train/0/4436.png
#   inflating: /content/data/EDD-dataset/train/0/7659.png
#   inflating: /content/data/EDD-dataset/train/0/5502.png
#   inflating: /content/data/EDD-dataset/train/0/5264.png
#   inflating: /content/data/EDD-dataset/train/0/7467.png
#   inflating: /content/data/EDD-dataset/train/0/4608.png
#   inflating: /content/data/EDD-dataset/train/0/7301.png
#   inflating: /content/data/EDD-dataset/train/0/4620.png
#   inflating: /content/data/EDD-dataset/train/0/6037.png
#   inflating: /content/data/EDD-dataset/train/0/5258.png
#   inflating: /content/data/EDD-dataset/train/0/4146.png
#   inflating: /content/data/EDD-dataset/train/0/4152.png
#   inflating: /content/data/EDD-dataset/train/0/6023.png
#   inflating: /content/data/EDD-dataset/train/0/4153.png
#   inflating: /content/data/EDD-dataset/train/0/6022.png
#   inflating: /content/data/EDD-dataset/train/0/6036.png
#   inflating: /content/data/EDD-dataset/train/0/4147.png
#   inflating: /content/data/EDD-dataset/train/0/5259.png
#   inflating: /content/data/EDD-dataset/train/0/7466.png
#   inflating: /content/data/EDD-dataset/train/0/7300.png
#   inflating: /content/data/EDD-dataset/train/0/4609.png
#   inflating: /content/data/EDD-dataset/train/0/5503.png
#   inflating: /content/data/EDD-dataset/train/0/4437.png
#   inflating: /content/data/EDD-dataset/train/0/7658.png
#   inflating: /content/data/EDD-dataset/train/0/7894.png
#   inflating: /content/data/EDD-dataset/train/0/4423.png
#   inflating: /content/data/EDD-dataset/train/0/6234.png
#   inflating: /content/data/EDD-dataset/train/0/7664.png
#   inflating: /content/data/EDD-dataset/train/0/6208.png
#   inflating: /content/data/EDD-dataset/train/0/7843.png
#   inflating: /content/data/EDD-dataset/train/0/5098.png
#   inflating: /content/data/EDD-dataset/train/0/5926.png
#   inflating: /content/data/EDD-dataset/train/0/3.png
#   inflating: /content/data/EDD-dataset/train/0/4543.png
#   inflating: /content/data/EDD-dataset/train/0/6432.png
#   inflating: /content/data/EDD-dataset/train/0/5649.png
#   inflating: /content/data/EDD-dataset/train/0/6340.png
#   inflating: /content/data/EDD-dataset/train/0/5661.png
#   inflating: /content/data/EDD-dataset/train/0/6368.png
#   inflating: /content/data/EDD-dataset/train/0/7710.png
#   inflating: /content/data/EDD-dataset/train/0/2668.png
#   inflating: /content/data/EDD-dataset/train/0/3562.png
#   inflating: /content/data/EDD-dataset/train/0/7704.png
#   inflating: /content/data/EDD-dataset/train/0/7937.png
#   inflating: /content/data/EDD-dataset/train/0/2873.png
#   inflating: /content/data/EDD-dataset/train/0/2867.png
#   inflating: /content/data/EDD-dataset/train/0/5339.png
#   inflating: /content/data/EDD-dataset/train/0/2456.png
#   inflating: /content/data/EDD-dataset/train/0/4999.png
#   inflating: /content/data/EDD-dataset/train/0/6156.png
#   inflating: /content/data/EDD-dataset/train/0/6142.png
#   inflating: /content/data/EDD-dataset/train/0/7512.png
#   inflating: /content/data/EDD-dataset/train/0/8147.png
#   inflating: /content/data/EDD-dataset/train/0/5463.png
#   inflating: /content/data/EDD-dataset/train/0/7260.png
#   inflating: /content/data/EDD-dataset/train/0/7506.png
#   inflating: /content/data/EDD-dataset/train/0/6195.png
#   inflating: /content/data/EDD-dataset/train/0/2481.png
#   inflating: /content/data/EDD-dataset/train/0/4966.png
#   inflating: /content/data/EDD-dataset/train/0/4964.png
#   inflating: /content/data/EDD-dataset/train/0/3979.png
#   inflating: /content/data/EDD-dataset/train/0/4958.png
#   inflating: /content/data/EDD-dataset/train/0/6197.png
#   inflating: /content/data/EDD-dataset/train/0/7289.png
#   inflating: /content/data/EDD-dataset/train/0/2483.png
#   inflating: /content/data/EDD-dataset/train/0/6183.png
#   inflating: /content/data/EDD-dataset/train/0/5461.png
#   inflating: /content/data/EDD-dataset/train/0/8145.png
#   inflating: /content/data/EDD-dataset/train/0/7510.png
#   inflating: /content/data/EDD-dataset/train/0/4019.png
#   inflating: /content/data/EDD-dataset/train/0/2468.png
#   inflating: /content/data/EDD-dataset/train/0/8151.png
#   inflating: /content/data/EDD-dataset/train/0/7262.png
#   inflating: /content/data/EDD-dataset/train/0/5475.png
#   inflating: /content/data/EDD-dataset/train/0/8179.png
#   inflating: /content/data/EDD-dataset/train/0/6154.png
#   inflating: /content/data/EDD-dataset/train/0/2454.png
#   inflating: /content/data/EDD-dataset/train/0/3038.png
#   inflating: /content/data/EDD-dataset/train/0/6140.png
#   inflating: /content/data/EDD-dataset/train/0/2871.png
#   inflating: /content/data/EDD-dataset/train/0/7935.png
#   inflating: /content/data/EDD-dataset/train/0/5663.png
#   inflating: /content/data/EDD-dataset/train/0/4569.png
#   inflating: /content/data/EDD-dataset/train/0/5677.png
#   inflating: /content/data/EDD-dataset/train/0/7706.png
#   inflating: /content/data/EDD-dataset/train/0/3560.png
#   inflating: /content/data/EDD-dataset/train/0/6430.png
#   inflating: /content/data/EDD-dataset/train/0/4541.png
#   inflating: /content/data/EDD-dataset/train/0/1.png
#   inflating: /content/data/EDD-dataset/train/0/6356.png
#   inflating: /content/data/EDD-dataset/train/0/6342.png
#   inflating: /content/data/EDD-dataset/train/0/5918.png
#   inflating: /content/data/EDD-dataset/train/0/7841.png
#   inflating: /content/data/EDD-dataset/train/0/5924.png
#   inflating: /content/data/EDD-dataset/train/0/7666.png
#   inflating: /content/data/EDD-dataset/train/0/4409.png
#   inflating: /content/data/EDD-dataset/train/0/4435.png
#   inflating: /content/data/EDD-dataset/train/0/6236.png
#   inflating: /content/data/EDD-dataset/train/0/4421.png
#   inflating: /content/data/EDD-dataset/train/0/3428.png
#   inflating: /content/data/EDD-dataset/train/0/7896.png
#   inflating: /content/data/EDD-dataset/train/0/4838.png
#   inflating: /content/data/EDD-dataset/train/0/7302.png
#   inflating: /content/data/EDD-dataset/train/0/7464.png
#   inflating: /content/data/EDD-dataset/train/0/5501.png
#   inflating: /content/data/EDD-dataset/train/0/6020.png
#   inflating: /content/data/EDD-dataset/train/0/4151.png
#   inflating: /content/data/EDD-dataset/train/0/7458.png
#   inflating: /content/data/EDD-dataset/train/0/4145.png
#   inflating: /content/data/EDD-dataset/train/0/6034.png
#   inflating: /content/data/EDD-dataset/train/0/4144.png
#   inflating: /content/data/EDD-dataset/train/0/6035.png
#   inflating: /content/data/EDD-dataset/train/0/6021.png
#   inflating: /content/data/EDD-dataset/train/0/7459.png
#   inflating: /content/data/EDD-dataset/train/0/4150.png
#   inflating: /content/data/EDD-dataset/train/0/5500.png
#   inflating: /content/data/EDD-dataset/train/0/7303.png
#   inflating: /content/data/EDD-dataset/train/0/7465.png
#   inflating: /content/data/EDD-dataset/train/0/4839.png
#   inflating: /content/data/EDD-dataset/train/0/4420.png
#   inflating: /content/data/EDD-dataset/train/0/6237.png
#   inflating: /content/data/EDD-dataset/train/0/7129.png
#   inflating: /content/data/EDD-dataset/train/0/7897.png
#   inflating: /content/data/EDD-dataset/train/0/3429.png
#   inflating: /content/data/EDD-dataset/train/0/4434.png
#   inflating: /content/data/EDD-dataset/train/0/3373.png
#   inflating: /content/data/EDD-dataset/train/0/7667.png
#   inflating: /content/data/EDD-dataset/train/0/4408.png
#   inflating: /content/data/EDD-dataset/train/0/5925.png
#   inflating: /content/data/EDD-dataset/train/0/7840.png
#   inflating: /content/data/EDD-dataset/train/0/5919.png
#   inflating: /content/data/EDD-dataset/train/0/6343.png
#   inflating: /content/data/EDD-dataset/train/0/6431.png
#   inflating: /content/data/EDD-dataset/train/0/6357.png
#   inflating: /content/data/EDD-dataset/train/0/0.png
#   inflating: /content/data/EDD-dataset/train/0/4540.png
#   inflating: /content/data/EDD-dataset/train/0/5676.png
#   inflating: /content/data/EDD-dataset/train/0/4568.png
#   inflating: /content/data/EDD-dataset/train/0/3561.png
#   inflating: /content/data/EDD-dataset/train/0/7707.png
#   inflating: /content/data/EDD-dataset/train/0/5662.png
#   inflating: /content/data/EDD-dataset/train/0/7934.png
#   inflating: /content/data/EDD-dataset/train/0/2870.png
#   inflating: /content/data/EDD-dataset/train/0/6141.png
#   inflating: /content/data/EDD-dataset/train/0/3039.png
#   inflating: /content/data/EDD-dataset/train/0/6155.png
#   inflating: /content/data/EDD-dataset/train/0/8178.png
#   inflating: /content/data/EDD-dataset/train/0/2455.png
#   inflating: /content/data/EDD-dataset/train/0/5474.png
#   inflating: /content/data/EDD-dataset/train/0/7263.png
#   inflating: /content/data/EDD-dataset/train/0/8150.png
#   inflating: /content/data/EDD-dataset/train/0/8144.png
#   inflating: /content/data/EDD-dataset/train/0/5460.png
#   inflating: /content/data/EDD-dataset/train/0/7511.png
#   inflating: /content/data/EDD-dataset/train/0/2482.png
#   inflating: /content/data/EDD-dataset/train/0/6182.png
#   inflating: /content/data/EDD-dataset/train/0/6196.png
#   inflating: /content/data/EDD-dataset/train/0/4959.png
#   inflating: /content/data/EDD-dataset/train/0/3978.png
#   inflating: /content/data/EDD-dataset/train/0/4965.png
#   inflating: /content/data/EDD-dataset/train/11/6602.png
#   inflating: /content/data/EDD-dataset/train/11/610.png
#   inflating: /content/data/EDD-dataset/train/11/604.png
#   inflating: /content/data/EDD-dataset/train/11/837.png
#   inflating: /content/data/EDD-dataset/train/11/2100.png
#   inflating: /content/data/EDD-dataset/train/11/3550.png
#   inflating: /content/data/EDD-dataset/train/11/3222.png
#   inflating: /content/data/EDD-dataset/train/11/7871.png
#   inflating: /content/data/EDD-dataset/train/11/566.png
#   inflating: /content/data/EDD-dataset/train/11/572.png
#   inflating: /content/data/EDD-dataset/train/11/599.png
#   inflating: /content/data/EDD-dataset/train/11/1019.png
#   inflating: /content/data/EDD-dataset/train/11/1031.png
#   inflating: /content/data/EDD-dataset/train/11/7454.png
#   inflating: /content/data/EDD-dataset/train/11/1025.png
#   inflating: /content/data/EDD-dataset/train/11/1024.png
#   inflating: /content/data/EDD-dataset/train/11/7455.png
#   inflating: /content/data/EDD-dataset/train/11/1030.png
#   inflating: /content/data/EDD-dataset/train/11/2539.png
#   inflating: /content/data/EDD-dataset/train/11/1018.png
#   inflating: /content/data/EDD-dataset/train/11/598.png
#   inflating: /content/data/EDD-dataset/train/11/573.png
#   inflating: /content/data/EDD-dataset/train/11/567.png
#   inflating: /content/data/EDD-dataset/train/11/7870.png
#   inflating: /content/data/EDD-dataset/train/11/3223.png
#   inflating: /content/data/EDD-dataset/train/11/3551.png
#   inflating: /content/data/EDD-dataset/train/11/2101.png
#   inflating: /content/data/EDD-dataset/train/11/836.png
#   inflating: /content/data/EDD-dataset/train/11/605.png
#   inflating: /content/data/EDD-dataset/train/11/611.png
#   inflating: /content/data/EDD-dataset/train/11/4772.png
#   inflating: /content/data/EDD-dataset/train/11/6603.png
#   inflating: /content/data/EDD-dataset/train/11/6601.png
#   inflating: /content/data/EDD-dataset/train/11/4770.png
#   inflating: /content/data/EDD-dataset/train/11/607.png
#   inflating: /content/data/EDD-dataset/train/11/613.png
#   inflating: /content/data/EDD-dataset/train/11/2103.png
#   inflating: /content/data/EDD-dataset/train/11/834.png
#   inflating: /content/data/EDD-dataset/train/11/3209.png
#   inflating: /content/data/EDD-dataset/train/11/3221.png
#   inflating: /content/data/EDD-dataset/train/11/3553.png
#   inflating: /content/data/EDD-dataset/train/11/7872.png
#   inflating: /content/data/EDD-dataset/train/11/559.png
#   inflating: /content/data/EDD-dataset/train/11/571.png
#   inflating: /content/data/EDD-dataset/train/11/565.png
#   inflating: /content/data/EDD-dataset/train/11/7457.png
#   inflating: /content/data/EDD-dataset/train/11/6749.png
#   inflating: /content/data/EDD-dataset/train/11/1026.png
#   inflating: /content/data/EDD-dataset/train/11/1027.png
#   inflating: /content/data/EDD-dataset/train/11/6748.png
#   inflating: /content/data/EDD-dataset/train/11/7456.png
#   inflating: /content/data/EDD-dataset/train/11/564.png
#   inflating: /content/data/EDD-dataset/train/11/570.png
#   inflating: /content/data/EDD-dataset/train/11/558.png
#   inflating: /content/data/EDD-dataset/train/11/7873.png
#   inflating: /content/data/EDD-dataset/train/11/3552.png
#   inflating: /content/data/EDD-dataset/train/11/3220.png
#   inflating: /content/data/EDD-dataset/train/11/835.png
#   inflating: /content/data/EDD-dataset/train/11/3208.png
#   inflating: /content/data/EDD-dataset/train/11/2102.png
#   inflating: /content/data/EDD-dataset/train/11/612.png
#   inflating: /content/data/EDD-dataset/train/11/606.png
#   inflating: /content/data/EDD-dataset/train/11/6600.png
#   inflating: /content/data/EDD-dataset/train/11/4771.png
#   inflating: /content/data/EDD-dataset/train/11/414.png
#   inflating: /content/data/EDD-dataset/train/11/6604.png
#   inflating: /content/data/EDD-dataset/train/11/6610.png
#   inflating: /content/data/EDD-dataset/train/11/602.png
#   inflating: /content/data/EDD-dataset/train/11/3224.png
#   inflating: /content/data/EDD-dataset/train/11/3556.png
#   inflating: /content/data/EDD-dataset/train/11/65.png
#   inflating: /content/data/EDD-dataset/train/11/3218.png
#   inflating: /content/data/EDD-dataset/train/11/2106.png
#   inflating: /content/data/EDD-dataset/train/11/2112.png
#   inflating: /content/data/EDD-dataset/train/11/831.png
#   inflating: /content/data/EDD-dataset/train/11/2099.png
#   inflating: /content/data/EDD-dataset/train/11/6599.png
#   inflating: /content/data/EDD-dataset/train/11/7877.png
#   inflating: /content/data/EDD-dataset/train/11/574.png
#   inflating: /content/data/EDD-dataset/train/11/560.png
#   inflating: /content/data/EDD-dataset/train/11/1023.png
#   inflating: /content/data/EDD-dataset/train/11/1022.png
#   inflating: /content/data/EDD-dataset/train/11/7453.png
#   inflating: /content/data/EDD-dataset/train/11/561.png
#   inflating: /content/data/EDD-dataset/train/11/575.png
#   inflating: /content/data/EDD-dataset/train/11/7876.png
#   inflating: /content/data/EDD-dataset/train/11/2098.png
#   inflating: /content/data/EDD-dataset/train/11/6598.png
#   inflating: /content/data/EDD-dataset/train/11/830.png
#   inflating: /content/data/EDD-dataset/train/11/2107.png
#   inflating: /content/data/EDD-dataset/train/11/3219.png
#   inflating: /content/data/EDD-dataset/train/11/3557.png
#   inflating: /content/data/EDD-dataset/train/11/3225.png
#   inflating: /content/data/EDD-dataset/train/11/603.png
#   inflating: /content/data/EDD-dataset/train/11/6611.png
#   inflating: /content/data/EDD-dataset/train/11/6605.png
#   inflating: /content/data/EDD-dataset/train/11/415.png
#   inflating: /content/data/EDD-dataset/train/11/417.png
#   inflating: /content/data/EDD-dataset/train/11/6607.png
#   inflating: /content/data/EDD-dataset/train/11/615.png
#   inflating: /content/data/EDD-dataset/train/11/7096.png
#   inflating: /content/data/EDD-dataset/train/11/601.png
#   inflating: /content/data/EDD-dataset/train/11/3227.png
#   inflating: /content/data/EDD-dataset/train/11/832.png
#   inflating: /content/data/EDD-dataset/train/11/2111.png
#   inflating: /content/data/EDD-dataset/train/11/2105.png
#   inflating: /content/data/EDD-dataset/train/11/7874.png
#   inflating: /content/data/EDD-dataset/train/11/563.png
#   inflating: /content/data/EDD-dataset/train/11/577.png
#   inflating: /content/data/EDD-dataset/train/11/1020.png
#   inflating: /content/data/EDD-dataset/train/11/588.png
#   inflating: /content/data/EDD-dataset/train/11/589.png
#   inflating: /content/data/EDD-dataset/train/11/1021.png
#   inflating: /content/data/EDD-dataset/train/11/576.png
#   inflating: /content/data/EDD-dataset/train/11/562.png
#   inflating: /content/data/EDD-dataset/train/11/7875.png
#   inflating: /content/data/EDD-dataset/train/11/4398.png
#   inflating: /content/data/EDD-dataset/train/11/2104.png
#   inflating: /content/data/EDD-dataset/train/11/833.png
#   inflating: /content/data/EDD-dataset/train/11/2110.png
#   inflating: /content/data/EDD-dataset/train/11/3226.png
#   inflating: /content/data/EDD-dataset/train/11/3554.png
#   inflating: /content/data/EDD-dataset/train/11/7083.png
#   inflating: /content/data/EDD-dataset/train/11/600.png
#   inflating: /content/data/EDD-dataset/train/11/614.png
#   inflating: /content/data/EDD-dataset/train/11/7097.png
#   inflating: /content/data/EDD-dataset/train/11/6606.png
#   inflating: /content/data/EDD-dataset/train/11/4950.png
#   inflating: /content/data/EDD-dataset/train/11/416.png
#   inflating: /content/data/EDD-dataset/train/11/6661.png
#   inflating: /content/data/EDD-dataset/train/11/4274.png
#   inflating: /content/data/EDD-dataset/train/11/4315.png
#   inflating: /content/data/EDD-dataset/train/11/6662.png
#   inflating: /content/data/EDD-dataset/train/11/4263.png
#   inflating: /content/data/EDD-dataset/train/11/7408.png
#   inflating: /content/data/EDD-dataset/train/11/7409.png
#   inflating: /content/data/EDD-dataset/train/11/7179.png
#   inflating: /content/data/EDD-dataset/train/11/4316.png
#   inflating: /content/data/EDD-dataset/train/11/4262.png
#   inflating: /content/data/EDD-dataset/train/11/8128.png
#   inflating: /content/data/EDD-dataset/train/11/6663.png
#   inflating: /content/data/EDD-dataset/train/11/4528.png
#   inflating: /content/data/EDD-dataset/train/11/4272.png
#   inflating: /content/data/EDD-dataset/train/11/4266.png
#   inflating: /content/data/EDD-dataset/train/11/7182.png
#   inflating: /content/data/EDD-dataset/train/11/6263.png
#   inflating: /content/data/EDD-dataset/train/11/4138.png
#   inflating: /content/data/EDD-dataset/train/11/4139.png
#   inflating: /content/data/EDD-dataset/train/11/6262.png
#   inflating: /content/data/EDD-dataset/train/11/933.png
#   inflating: /content/data/EDD-dataset/train/11/4267.png
#   inflating: /content/data/EDD-dataset/train/11/4273.png
#   inflating: /content/data/EDD-dataset/train/11/4529.png
#   inflating: /content/data/EDD-dataset/train/11/4265.png
#   inflating: /content/data/EDD-dataset/train/11/4271.png
#   inflating: /content/data/EDD-dataset/train/11/7181.png
#   inflating: /content/data/EDD-dataset/train/11/6261.png
#   inflating: /content/data/EDD-dataset/train/11/7180.png
#   inflating: /content/data/EDD-dataset/train/11/4270.png
#   inflating: /content/data/EDD-dataset/train/11/4264.png
#   inflating: /content/data/EDD-dataset/train/11/8123.png
#   inflating: /content/data/EDD-dataset/train/11/4527.png
#   inflating: /content/data/EDD-dataset/train/11/4269.png
#   inflating: /content/data/EDD-dataset/train/11/4137.png
#   inflating: /content/data/EDD-dataset/train/11/4268.png
#   inflating: /content/data/EDD-dataset/train/11/4526.png
#   inflating: /content/data/EDD-dataset/train/11/8122.png
#   inflating: /content/data/EDD-dataset/train/11/4724.png
#   inflating: /content/data/EDD-dataset/train/11/4530.png
#   inflating: /content/data/EDD-dataset/train/11/4524.png
#   inflating: /content/data/EDD-dataset/train/11/4525.png
#   inflating: /content/data/EDD-dataset/train/11/4531.png
#   inflating: /content/data/EDD-dataset/train/11/8121.png
#   inflating: /content/data/EDD-dataset/train/11/8125.png
#   inflating: /content/data/EDD-dataset/train/11/7000.png
#   inflating: /content/data/EDD-dataset/train/11/7410.png
#   inflating: /content/data/EDD-dataset/train/11/2540.png
#   inflating: /content/data/EDD-dataset/train/11/2541.png
#   inflating: /content/data/EDD-dataset/train/11/7411.png
#   inflating: /content/data/EDD-dataset/train/11/4534.png
#   inflating: /content/data/EDD-dataset/train/11/8124.png
#   inflating: /content/data/EDD-dataset/train/11/8126.png
#   inflating: /content/data/EDD-dataset/train/11/290.png
#   inflating: /content/data/EDD-dataset/train/11/7412.png
#   inflating: /content/data/EDD-dataset/train/11/7176.png
#   inflating: /content/data/EDD-dataset/train/11/4523.png
#   inflating: /content/data/EDD-dataset/train/11/8127.png
#   inflating: /content/data/EDD-dataset/train/11/4949.png
#   inflating: /content/data/EDD-dataset/train/11/3217.png
#   inflating: /content/data/EDD-dataset/train/11/2109.png
#   inflating: /content/data/EDD-dataset/train/11/4395.png
#   inflating: /content/data/EDD-dataset/train/11/6582.png
#   inflating: /content/data/EDD-dataset/train/11/6596.png
#   inflating: /content/data/EDD-dataset/train/11/2096.png
#   inflating: /content/data/EDD-dataset/train/11/7878.png
#   inflating: /content/data/EDD-dataset/train/11/4140.png
#   inflating: /content/data/EDD-dataset/train/11/584.png
#   inflating: /content/data/EDD-dataset/train/11/590.png
#   inflating: /content/data/EDD-dataset/train/11/591.png
#   inflating: /content/data/EDD-dataset/train/11/585.png
#   inflating: /content/data/EDD-dataset/train/11/4141.png
#   inflating: /content/data/EDD-dataset/train/11/6597.png
#   inflating: /content/data/EDD-dataset/train/11/2097.png
#   inflating: /content/data/EDD-dataset/train/11/6583.png
#   inflating: /content/data/EDD-dataset/train/11/2108.png
#   inflating: /content/data/EDD-dataset/train/11/3216.png
#   inflating: /content/data/EDD-dataset/train/11/4948.png
#   inflating: /content/data/EDD-dataset/train/11/418.png
#   inflating: /content/data/EDD-dataset/train/11/6608.png
#   inflating: /content/data/EDD-dataset/train/11/7099.png
#   inflating: /content/data/EDD-dataset/train/11/3228.png
#   inflating: /content/data/EDD-dataset/train/11/3214.png
#   inflating: /content/data/EDD-dataset/train/11/2095.png
#   inflating: /content/data/EDD-dataset/train/11/6595.png
#   inflating: /content/data/EDD-dataset/train/11/4396.png
#   inflating: /content/data/EDD-dataset/train/11/6581.png
#   inflating: /content/data/EDD-dataset/train/11/578.png
#   inflating: /content/data/EDD-dataset/train/11/6754.png
#   inflating: /content/data/EDD-dataset/train/11/593.png
#   inflating: /content/data/EDD-dataset/train/11/587.png
#   inflating: /content/data/EDD-dataset/train/11/586.png
#   inflating: /content/data/EDD-dataset/train/11/592.png
#   inflating: /content/data/EDD-dataset/train/11/4142.png
#   inflating: /content/data/EDD-dataset/train/11/4817.png
#   inflating: /content/data/EDD-dataset/train/11/579.png
#   inflating: /content/data/EDD-dataset/train/11/4397.png
#   inflating: /content/data/EDD-dataset/train/11/2094.png
#   inflating: /content/data/EDD-dataset/train/11/6594.png
#   inflating: /content/data/EDD-dataset/train/11/3215.png
#   inflating: /content/data/EDD-dataset/train/11/7098.png
#   inflating: /content/data/EDD-dataset/train/11/6609.png
#   inflating: /content/data/EDD-dataset/train/11/419.png
#   inflating: /content/data/EDD-dataset/train/11/421.png
#   inflating: /content/data/EDD-dataset/train/11/838.png
#   inflating: /content/data/EDD-dataset/train/11/3205.png
#   inflating: /content/data/EDD-dataset/train/11/3211.png
#   inflating: /content/data/EDD-dataset/train/11/569.png
#   inflating: /content/data/EDD-dataset/train/11/596.png
#   inflating: /content/data/EDD-dataset/train/11/582.png
#   inflating: /content/data/EDD-dataset/train/11/1016.png
#   inflating: /content/data/EDD-dataset/train/11/6751.png
#   inflating: /content/data/EDD-dataset/train/11/6750.png
#   inflating: /content/data/EDD-dataset/train/11/1017.png
#   inflating: /content/data/EDD-dataset/train/11/583.png
#   inflating: /content/data/EDD-dataset/train/11/597.png
#   inflating: /content/data/EDD-dataset/train/11/568.png
#   inflating: /content/data/EDD-dataset/train/11/6591.png
#   inflating: /content/data/EDD-dataset/train/11/3210.png
#   inflating: /content/data/EDD-dataset/train/11/420.png
#   inflating: /content/data/EDD-dataset/train/11/422.png
#   inflating: /content/data/EDD-dataset/train/11/608.png
#   inflating: /content/data/EDD-dataset/train/11/3212.png
#   inflating: /content/data/EDD-dataset/train/11/3206.png
#   inflating: /content/data/EDD-dataset/train/11/7869.png
#   inflating: /content/data/EDD-dataset/train/11/4390.png
#   inflating: /content/data/EDD-dataset/train/11/6593.png
#   inflating: /content/data/EDD-dataset/train/11/6578.png
#   inflating: /content/data/EDD-dataset/train/11/581.png
#   inflating: /content/data/EDD-dataset/train/11/595.png
#   inflating: /content/data/EDD-dataset/train/11/1029.png
#   inflating: /content/data/EDD-dataset/train/11/6752.png
#   inflating: /content/data/EDD-dataset/train/11/6753.png
#   inflating: /content/data/EDD-dataset/train/11/1028.png
#   inflating: /content/data/EDD-dataset/train/11/594.png
#   inflating: /content/data/EDD-dataset/train/11/580.png
#   inflating: /content/data/EDD-dataset/train/11/6579.png
#   inflating: /content/data/EDD-dataset/train/11/6592.png
#   inflating: /content/data/EDD-dataset/train/11/7868.png
#   inflating: /content/data/EDD-dataset/train/11/3549.png
#   inflating: /content/data/EDD-dataset/train/11/3207.png
#   inflating: /content/data/EDD-dataset/train/11/3213.png
#   inflating: /content/data/EDD-dataset/train/11/609.png
#   inflating: /content/data/EDD-dataset/train/11/7505.png
#   inflating: /content/data/EDD-dataset/train/11/423.png
#   inflating: /content/data/EDD-dataset/train/7/1810.png
#   inflating: /content/data/EDD-dataset/train/7/1186.png
#   inflating: /content/data/EDD-dataset/train/7/4940.png
#   inflating: /content/data/EDD-dataset/train/7/1192.png
#   inflating: /content/data/EDD-dataset/train/7/1179.png
#   inflating: /content/data/EDD-dataset/train/7/5323.png
#   inflating: /content/data/EDD-dataset/train/7/1145.png
#   inflating: /content/data/EDD-dataset/train/7/1623.png
#   inflating: /content/data/EDD-dataset/train/7/3593.png
#   inflating: /content/data/EDD-dataset/train/7/3587.png
#   inflating: /content/data/EDD-dataset/train/7/7736.png
#   inflating: /content/data/EDD-dataset/train/7/5135.png
#   inflating: /content/data/EDD-dataset/train/7/758.png
#   inflating: /content/data/EDD-dataset/train/7/764.png
#   inflating: /content/data/EDD-dataset/train/7/770.png
#   inflating: /content/data/EDD-dataset/train/7/5082.png
#   inflating: /content/data/EDD-dataset/train/7/4820.png
#   inflating: /content/data/EDD-dataset/train/7/2289.png
#   inflating: /content/data/EDD-dataset/train/7/3626.png
#   inflating: /content/data/EDD-dataset/train/7/3632.png
#   inflating: /content/data/EDD-dataset/train/7/3633.png
#   inflating: /content/data/EDD-dataset/train/7/3627.png
#   inflating: /content/data/EDD-dataset/train/7/2288.png
#   inflating: /content/data/EDD-dataset/train/7/4821.png
#   inflating: /content/data/EDD-dataset/train/7/4404.png
#   inflating: /content/data/EDD-dataset/train/7/5083.png
#   inflating: /content/data/EDD-dataset/train/7/765.png
#   inflating: /content/data/EDD-dataset/train/7/2920.png
#   inflating: /content/data/EDD-dataset/train/7/759.png
#   inflating: /content/data/EDD-dataset/train/7/5134.png
#   inflating: /content/data/EDD-dataset/train/7/7737.png
#   inflating: /content/data/EDD-dataset/train/7/3586.png
#   inflating: /content/data/EDD-dataset/train/7/3592.png
#   inflating: /content/data/EDD-dataset/train/7/1144.png
#   inflating: /content/data/EDD-dataset/train/7/5322.png
#   inflating: /content/data/EDD-dataset/train/7/1622.png
#   inflating: /content/data/EDD-dataset/train/7/1178.png
#   inflating: /content/data/EDD-dataset/train/7/1187.png
#   inflating: /content/data/EDD-dataset/train/7/4941.png
#   inflating: /content/data/EDD-dataset/train/7/1811.png
#   inflating: /content/data/EDD-dataset/train/7/1813.png
#   inflating: /content/data/EDD-dataset/train/7/1191.png
#   inflating: /content/data/EDD-dataset/train/7/4943.png
#   inflating: /content/data/EDD-dataset/train/7/1185.png
#   inflating: /content/data/EDD-dataset/train/7/5308.png
#   inflating: /content/data/EDD-dataset/train/7/1608.png
#   inflating: /content/data/EDD-dataset/train/7/2301.png
#   inflating: /content/data/EDD-dataset/train/7/5334.png
#   inflating: /content/data/EDD-dataset/train/7/1620.png
#   inflating: /content/data/EDD-dataset/train/7/5320.png
#   inflating: /content/data/EDD-dataset/train/7/3590.png
#   inflating: /content/data/EDD-dataset/train/7/5136.png
#   inflating: /content/data/EDD-dataset/train/7/7735.png
#   inflating: /content/data/EDD-dataset/train/7/5122.png
#   inflating: /content/data/EDD-dataset/train/7/2088.png
#   inflating: /content/data/EDD-dataset/train/7/5081.png
#   inflating: /content/data/EDD-dataset/train/7/767.png
#   inflating: /content/data/EDD-dataset/train/7/4823.png
#   inflating: /content/data/EDD-dataset/train/7/3619.png
#   inflating: /content/data/EDD-dataset/train/7/3631.png
#   inflating: /content/data/EDD-dataset/train/7/1998.png
#   inflating: /content/data/EDD-dataset/train/7/3625.png
#   inflating: /content/data/EDD-dataset/train/7/3624.png
#   inflating: /content/data/EDD-dataset/train/7/3630.png
#   inflating: /content/data/EDD-dataset/train/7/1999.png
#   inflating: /content/data/EDD-dataset/train/7/3618.png
#   inflating: /content/data/EDD-dataset/train/7/4822.png
#   inflating: /content/data/EDD-dataset/train/7/766.png
#   inflating: /content/data/EDD-dataset/train/7/2089.png
#   inflating: /content/data/EDD-dataset/train/7/5080.png
#   inflating: /content/data/EDD-dataset/train/7/5123.png
#   inflating: /content/data/EDD-dataset/train/7/5137.png
#   inflating: /content/data/EDD-dataset/train/7/3591.png
#   inflating: /content/data/EDD-dataset/train/7/1621.png
#   inflating: /content/data/EDD-dataset/train/7/1147.png
#   inflating: /content/data/EDD-dataset/train/7/5321.png
#   inflating: /content/data/EDD-dataset/train/7/5335.png
#   inflating: /content/data/EDD-dataset/train/7/5309.png
#   inflating: /content/data/EDD-dataset/train/7/2300.png
#   inflating: /content/data/EDD-dataset/train/7/1609.png
#   inflating: /content/data/EDD-dataset/train/7/4942.png
#   inflating: /content/data/EDD-dataset/train/7/1184.png
#   inflating: /content/data/EDD-dataset/train/7/1190.png
#   inflating: /content/data/EDD-dataset/train/7/1812.png
#   inflating: /content/data/EDD-dataset/train/7/1180.png
#   inflating: /content/data/EDD-dataset/train/7/4946.png
#   inflating: /content/data/EDD-dataset/train/7/1816.png
#   inflating: /content/data/EDD-dataset/train/7/5331.png
#   inflating: /content/data/EDD-dataset/train/7/5325.png
#   inflating: /content/data/EDD-dataset/train/7/1143.png
#   inflating: /content/data/EDD-dataset/train/7/1625.png
#   inflating: /content/data/EDD-dataset/train/7/5319.png
#   inflating: /content/data/EDD-dataset/train/7/1619.png
#   inflating: /content/data/EDD-dataset/train/7/3595.png
#   inflating: /content/data/EDD-dataset/train/7/5133.png
#   inflating: /content/data/EDD-dataset/train/7/1341.png
#   inflating: /content/data/EDD-dataset/train/7/5127.png
#   inflating: /content/data/EDD-dataset/train/7/5084.png
#   inflating: /content/data/EDD-dataset/train/7/5090.png
#   inflating: /content/data/EDD-dataset/train/7/762.png
#   inflating: /content/data/EDD-dataset/train/7/1235.png
#   inflating: /content/data/EDD-dataset/train/7/4403.png
#   inflating: /content/data/EDD-dataset/train/7/4826.png
#   inflating: /content/data/EDD-dataset/train/7/1745.png
#   inflating: /content/data/EDD-dataset/train/7/7452.png
#   inflating: /content/data/EDD-dataset/train/7/6994.png
#   inflating: /content/data/EDD-dataset/train/7/3634.png
#   inflating: /content/data/EDD-dataset/train/7/3620.png
#   inflating: /content/data/EDD-dataset/train/7/7446.png
#   inflating: /content/data/EDD-dataset/train/7/1751.png
#   inflating: /content/data/EDD-dataset/train/7/1989.png
#   inflating: /content/data/EDD-dataset/train/7/3608.png
#   inflating: /content/data/EDD-dataset/train/7/3609.png
#   inflating: /content/data/EDD-dataset/train/7/7447.png
#   inflating: /content/data/EDD-dataset/train/7/3621.png
#   inflating: /content/data/EDD-dataset/train/7/1988.png
#   inflating: /content/data/EDD-dataset/train/7/1750.png
#   inflating: /content/data/EDD-dataset/train/7/3635.png
#   inflating: /content/data/EDD-dataset/train/7/6995.png
#   inflating: /content/data/EDD-dataset/train/7/4827.png
#   inflating: /content/data/EDD-dataset/train/7/4402.png
#   inflating: /content/data/EDD-dataset/train/7/763.png
#   inflating: /content/data/EDD-dataset/train/7/5091.png
#   inflating: /content/data/EDD-dataset/train/7/5085.png
#   inflating: /content/data/EDD-dataset/train/7/5126.png
#   inflating: /content/data/EDD-dataset/train/7/1340.png
#   inflating: /content/data/EDD-dataset/train/7/5132.png
#   inflating: /content/data/EDD-dataset/train/7/3594.png
#   inflating: /content/data/EDD-dataset/train/7/5318.png
#   inflating: /content/data/EDD-dataset/train/7/1618.png
#   inflating: /content/data/EDD-dataset/train/7/1142.png
#   inflating: /content/data/EDD-dataset/train/7/5324.png
#   inflating: /content/data/EDD-dataset/train/7/1624.png
#   inflating: /content/data/EDD-dataset/train/7/1630.png
#   inflating: /content/data/EDD-dataset/train/7/5330.png
#   inflating: /content/data/EDD-dataset/train/7/1817.png
#   inflating: /content/data/EDD-dataset/train/7/1181.png
#   inflating: /content/data/EDD-dataset/train/7/4947.png
#   inflating: /content/data/EDD-dataset/train/7/4945.png
#   inflating: /content/data/EDD-dataset/train/7/1183.png
#   inflating: /content/data/EDD-dataset/train/7/1815.png
#   inflating: /content/data/EDD-dataset/train/7/1626.png
#   inflating: /content/data/EDD-dataset/train/7/2449.png
#   inflating: /content/data/EDD-dataset/train/7/5326.png
#   inflating: /content/data/EDD-dataset/train/7/1140.png
#   inflating: /content/data/EDD-dataset/train/7/5332.png
#   inflating: /content/data/EDD-dataset/train/7/3596.png
#   inflating: /content/data/EDD-dataset/train/7/5124.png
#   inflating: /content/data/EDD-dataset/train/7/5130.png
#   inflating: /content/data/EDD-dataset/train/7/761.png
#   inflating: /content/data/EDD-dataset/train/7/5087.png
#   inflating: /content/data/EDD-dataset/train/7/4399.png
#   inflating: /content/data/EDD-dataset/train/7/2918.png
#   inflating: /content/data/EDD-dataset/train/7/749.png
#   inflating: /content/data/EDD-dataset/train/7/1236.png
#   inflating: /content/data/EDD-dataset/train/7/4400.png
#   inflating: /content/data/EDD-dataset/train/7/5078.png
#   inflating: /content/data/EDD-dataset/train/7/2298.png
#   inflating: /content/data/EDD-dataset/train/7/4825.png
#   inflating: /content/data/EDD-dataset/train/7/4819.png
#   inflating: /content/data/EDD-dataset/train/7/1752.png
#   inflating: /content/data/EDD-dataset/train/7/3623.png
#   inflating: /content/data/EDD-dataset/train/7/7451.png
#   inflating: /content/data/EDD-dataset/train/7/6997.png
#   inflating: /content/data/EDD-dataset/train/7/3637.png
#   inflating: /content/data/EDD-dataset/train/7/1746.png
#   inflating: /content/data/EDD-dataset/train/7/3636.png
#   inflating: /content/data/EDD-dataset/train/7/6996.png
#   inflating: /content/data/EDD-dataset/train/7/7450.png
#   inflating: /content/data/EDD-dataset/train/7/1747.png
#   inflating: /content/data/EDD-dataset/train/7/1753.png
#   inflating: /content/data/EDD-dataset/train/7/3622.png
#   inflating: /content/data/EDD-dataset/train/7/4818.png
#   inflating: /content/data/EDD-dataset/train/7/4824.png
#   inflating: /content/data/EDD-dataset/train/7/2299.png
#   inflating: /content/data/EDD-dataset/train/7/4401.png
#   inflating: /content/data/EDD-dataset/train/7/5079.png
#   inflating: /content/data/EDD-dataset/train/7/1237.png
#   inflating: /content/data/EDD-dataset/train/7/748.png
#   inflating: /content/data/EDD-dataset/train/7/2919.png
#   inflating: /content/data/EDD-dataset/train/7/5086.png
#   inflating: /content/data/EDD-dataset/train/7/760.png
#   inflating: /content/data/EDD-dataset/train/7/5131.png
#   inflating: /content/data/EDD-dataset/train/7/5125.png
#   inflating: /content/data/EDD-dataset/train/7/3597.png
#   inflating: /content/data/EDD-dataset/train/7/5333.png
#   inflating: /content/data/EDD-dataset/train/7/1627.png
#   inflating: /content/data/EDD-dataset/train/7/1141.png
#   inflating: /content/data/EDD-dataset/train/7/5327.png
#   inflating: /content/data/EDD-dataset/train/7/2448.png
#   inflating: /content/data/EDD-dataset/train/7/1814.png
#   inflating: /content/data/EDD-dataset/train/7/1828.png
#   inflating: /content/data/EDD-dataset/train/7/4944.png
#   inflating: /content/data/EDD-dataset/train/7/1182.png
#   inflating: /content/data/EDD-dataset/train/7/1873.png
#   inflating: /content/data/EDD-dataset/train/7/1683.png
#   inflating: /content/data/EDD-dataset/train/7/1697.png
#   inflating: /content/data/EDD-dataset/train/7/2407.png
#   inflating: /content/data/EDD-dataset/train/7/1898.png
#   inflating: /content/data/EDD-dataset/train/7/1126.png
#   inflating: /content/data/EDD-dataset/train/7/7557.png
#   inflating: /content/data/EDD-dataset/train/7/1132.png
#   inflating: /content/data/EDD-dataset/train/7/7543.png
#   inflating: /content/data/EDD-dataset/train/7/673.png
#   inflating: /content/data/EDD-dataset/train/7/3282.png
#   inflating: /content/data/EDD-dataset/train/7/4512.png
#   inflating: /content/data/EDD-dataset/train/7/1324.png
#   inflating: /content/data/EDD-dataset/train/7/1456.png
#   inflating: /content/data/EDD-dataset/train/7/2003.png
#   inflating: /content/data/EDD-dataset/train/7/1250.png
#   inflating: /content/data/EDD-dataset/train/7/3321.png
#   inflating: /content/data/EDD-dataset/train/7/1522.png
#   inflating: /content/data/EDD-dataset/train/7/1244.png
#   inflating: /content/data/EDD-dataset/train/7/3876.png
#   inflating: /content/data/EDD-dataset/train/7/3645.png
#   inflating: /content/data/EDD-dataset/train/7/3889.png
#   inflating: /content/data/EDD-dataset/train/7/3651.png
#   inflating: /content/data/EDD-dataset/train/7/3650.png
#   inflating: /content/data/EDD-dataset/train/7/3888.png
#   inflating: /content/data/EDD-dataset/train/7/3644.png
#   inflating: /content/data/EDD-dataset/train/7/3877.png
#   inflating: /content/data/EDD-dataset/train/7/1523.png
#   inflating: /content/data/EDD-dataset/train/7/1245.png
#   inflating: /content/data/EDD-dataset/train/7/1251.png
#   inflating: /content/data/EDD-dataset/train/7/3320.png
#   inflating: /content/data/EDD-dataset/train/7/2002.png
#   inflating: /content/data/EDD-dataset/train/7/1457.png
#   inflating: /content/data/EDD-dataset/train/7/1325.png
#   inflating: /content/data/EDD-dataset/train/7/4513.png
#   inflating: /content/data/EDD-dataset/train/7/1319.png
#   inflating: /content/data/EDD-dataset/train/7/4507.png
#   inflating: /content/data/EDD-dataset/train/7/3283.png
#   inflating: /content/data/EDD-dataset/train/7/672.png
#   inflating: /content/data/EDD-dataset/train/7/7542.png
#   inflating: /content/data/EDD-dataset/train/7/1133.png
#   inflating: /content/data/EDD-dataset/train/7/1899.png
#   inflating: /content/data/EDD-dataset/train/7/7556.png
#   inflating: /content/data/EDD-dataset/train/7/1127.png
#   inflating: /content/data/EDD-dataset/train/7/2406.png
#   inflating: /content/data/EDD-dataset/train/7/1696.png
#   inflating: /content/data/EDD-dataset/train/7/1682.png
#   inflating: /content/data/EDD-dataset/train/7/1872.png
#   inflating: /content/data/EDD-dataset/train/7/1870.png
#   inflating: /content/data/EDD-dataset/train/7/1694.png
#   inflating: /content/data/EDD-dataset/train/7/2389.png
#   inflating: /content/data/EDD-dataset/train/7/2404.png
#   inflating: /content/data/EDD-dataset/train/7/1119.png
#   inflating: /content/data/EDD-dataset/train/7/2376.png
#   inflating: /content/data/EDD-dataset/train/7/1131.png
#   inflating: /content/data/EDD-dataset/train/7/7540.png
#   inflating: /content/data/EDD-dataset/train/7/1125.png
#   inflating: /content/data/EDD-dataset/train/7/7554.png
#   inflating: /content/data/EDD-dataset/train/7/3281.png
#   inflating: /content/data/EDD-dataset/train/7/1469.png
#   inflating: /content/data/EDD-dataset/train/7/4511.png
#   inflating: /content/data/EDD-dataset/train/7/1455.png
#   inflating: /content/data/EDD-dataset/train/7/1327.png
#   inflating: /content/data/EDD-dataset/train/7/738.png
#   inflating: /content/data/EDD-dataset/train/7/2000.png
#   inflating: /content/data/EDD-dataset/train/7/1247.png
#   inflating: /content/data/EDD-dataset/train/7/1521.png
#   inflating: /content/data/EDD-dataset/train/7/3322.png
#   inflating: /content/data/EDD-dataset/train/7/1253.png
#   inflating: /content/data/EDD-dataset/train/7/3875.png
#   inflating: /content/data/EDD-dataset/train/7/3652.png
#   inflating: /content/data/EDD-dataset/train/7/3646.png
#   inflating: /content/data/EDD-dataset/train/7/3647.png
#   inflating: /content/data/EDD-dataset/train/7/3653.png
#   inflating: /content/data/EDD-dataset/train/7/3874.png
#   inflating: /content/data/EDD-dataset/train/7/3323.png
#   inflating: /content/data/EDD-dataset/train/7/1252.png
#   inflating: /content/data/EDD-dataset/train/7/1246.png
#   inflating: /content/data/EDD-dataset/train/7/1520.png
#   inflating: /content/data/EDD-dataset/train/7/2001.png
#   inflating: /content/data/EDD-dataset/train/7/739.png
#   inflating: /content/data/EDD-dataset/train/7/1326.png
#   inflating: /content/data/EDD-dataset/train/7/4510.png
#   inflating: /content/data/EDD-dataset/train/7/1468.png
#   inflating: /content/data/EDD-dataset/train/7/671.png
#   inflating: /content/data/EDD-dataset/train/7/7555.png
#   inflating: /content/data/EDD-dataset/train/7/1124.png
#   inflating: /content/data/EDD-dataset/train/7/7541.png
#   inflating: /content/data/EDD-dataset/train/7/1130.png
#   inflating: /content/data/EDD-dataset/train/7/2377.png
#   inflating: /content/data/EDD-dataset/train/7/2405.png
#   inflating: /content/data/EDD-dataset/train/7/2388.png
#   inflating: /content/data/EDD-dataset/train/7/1695.png
#   inflating: /content/data/EDD-dataset/train/7/1871.png
#   inflating: /content/data/EDD-dataset/train/7/2398.png
#   inflating: /content/data/EDD-dataset/train/7/1691.png
#   inflating: /content/data/EDD-dataset/train/7/1685.png
#   inflating: /content/data/EDD-dataset/train/7/1875.png
#   inflating: /content/data/EDD-dataset/train/7/1134.png
#   inflating: /content/data/EDD-dataset/train/7/7545.png
#   inflating: /content/data/EDD-dataset/train/7/1120.png
#   inflating: /content/data/EDD-dataset/train/7/7551.png
#   inflating: /content/data/EDD-dataset/train/7/2401.png
#   inflating: /content/data/EDD-dataset/train/7/3284.png
#   inflating: /content/data/EDD-dataset/train/7/1322.png
#   inflating: /content/data/EDD-dataset/train/7/4514.png
#   inflating: /content/data/EDD-dataset/train/7/729.png
#   inflating: /content/data/EDD-dataset/train/7/1524.png
#   inflating: /content/data/EDD-dataset/train/7/1242.png
#   inflating: /content/data/EDD-dataset/train/7/1256.png
#   inflating: /content/data/EDD-dataset/train/7/1518.png
#   inflating: /content/data/EDD-dataset/train/7/2005.png
#   inflating: /content/data/EDD-dataset/train/7/3870.png
#   inflating: /content/data/EDD-dataset/train/7/1901.png
#   inflating: /content/data/EDD-dataset/train/7/3657.png
#   inflating: /content/data/EDD-dataset/train/7/3643.png
#   inflating: /content/data/EDD-dataset/train/7/3642.png
#   inflating: /content/data/EDD-dataset/train/7/3656.png
#   inflating: /content/data/EDD-dataset/train/7/3871.png
#   inflating: /content/data/EDD-dataset/train/7/1900.png
#   inflating: /content/data/EDD-dataset/train/7/2004.png
#   inflating: /content/data/EDD-dataset/train/7/1519.png
#   inflating: /content/data/EDD-dataset/train/7/1257.png
#   inflating: /content/data/EDD-dataset/train/7/1525.png
#   inflating: /content/data/EDD-dataset/train/7/1243.png
#   inflating: /content/data/EDD-dataset/train/7/728.png
#   inflating: /content/data/EDD-dataset/train/7/4515.png
#   inflating: /content/data/EDD-dataset/train/7/1323.png
#   inflating: /content/data/EDD-dataset/train/7/674.png
#   inflating: /content/data/EDD-dataset/train/7/3285.png
#   inflating: /content/data/EDD-dataset/train/7/2400.png
#   inflating: /content/data/EDD-dataset/train/7/7550.png
#   inflating: /content/data/EDD-dataset/train/7/1121.png
#   inflating: /content/data/EDD-dataset/train/7/7544.png
#   inflating: /content/data/EDD-dataset/train/7/1135.png
#   inflating: /content/data/EDD-dataset/train/7/1874.png
#   inflating: /content/data/EDD-dataset/train/7/1684.png
#   inflating: /content/data/EDD-dataset/train/7/1690.png
#   inflating: /content/data/EDD-dataset/train/7/2399.png
#   inflating: /content/data/EDD-dataset/train/7/1686.png
#   inflating: /content/data/EDD-dataset/train/7/1692.png
#   inflating: /content/data/EDD-dataset/train/7/1876.png
#   inflating: /content/data/EDD-dataset/train/7/1123.png
#   inflating: /content/data/EDD-dataset/train/7/7552.png
#   inflating: /content/data/EDD-dataset/train/7/1889.png
#   inflating: /content/data/EDD-dataset/train/7/1137.png
#   inflating: /content/data/EDD-dataset/train/7/7546.png
#   inflating: /content/data/EDD-dataset/train/7/2402.png
#   inflating: /content/data/EDD-dataset/train/7/3287.png
#   inflating: /content/data/EDD-dataset/train/7/138.png
#   inflating: /content/data/EDD-dataset/train/7/1321.png
#   inflating: /content/data/EDD-dataset/train/7/4517.png
#   inflating: /content/data/EDD-dataset/train/7/1255.png
#   inflating: /content/data/EDD-dataset/train/7/1241.png
#   inflating: /content/data/EDD-dataset/train/7/2006.png
#   inflating: /content/data/EDD-dataset/train/7/3318.png
#   inflating: /content/data/EDD-dataset/train/7/1269.png
#   inflating: /content/data/EDD-dataset/train/7/3867.png
# ...
#   inflating: /content/data/EDD-dataset/train/5/5966.png
#   inflating: /content/data/EDD-dataset/train/5/3442.png
#   inflating: /content/data/EDD-dataset/train/5/5999.png
#   inflating: /content/data/EDD-dataset/train/5/8073.png
#   inflating: /content/data/EDD-dataset/train/5/4112.png
#   inflating: /content/data/EDD-dataset/train/5/8072.png
#   inflating: /content/data/EDD-dataset/train/5/5998.png
#   inflating: /content/data/EDD-dataset/train/5/3443.png
#   inflating: /content/data/EDD-dataset/train/5/5967.png
#   inflating: /content/data/EDD-dataset/train/5/5973.png
#   inflating: /content/data/EDD-dataset/train/5/5783.png
#   inflating: /content/data/EDD-dataset/train/5/7194.png
#   inflating: /content/data/EDD-dataset/train/5/5797.png
#   inflating: /content/data/EDD-dataset/train/5/5620.png
#   inflating: /content/data/EDD-dataset/train/5/5813.png
#   inflating: /content/data/EDD-dataset/train/5/5807.png
#   inflating: /content/data/EDD-dataset/train/5/6683.png
#   inflating: /content/data/EDD-dataset/train/5/5836.png
#   inflating: /content/data/EDD-dataset/train/5/7012.png
#   inflating: /content/data/EDD-dataset/train/5/7006.png
#   inflating: /content/data/EDD-dataset/train/5/5956.png
#   inflating: /content/data/EDD-dataset/train/5/7199.png
#   inflating: /content/data/EDD-dataset/train/5/5995.png
#   inflating: /content/data/EDD-dataset/train/5/4876.png
#   inflating: /content/data/EDD-dataset/train/5/8080.png
#   inflating: /content/data/EDD-dataset/train/5/6720.png
#   inflating: /content/data/EDD-dataset/train/5/6734.png
#   inflating: /content/data/EDD-dataset/train/5/6721.png
#   inflating: /content/data/EDD-dataset/train/5/8081.png
#   inflating: /content/data/EDD-dataset/train/5/4877.png
#   inflating: /content/data/EDD-dataset/train/5/5994.png
#   inflating: /content/data/EDD-dataset/train/5/7198.png
#   inflating: /content/data/EDD-dataset/train/5/5957.png
#   inflating: /content/data/EDD-dataset/train/5/7007.png
#   inflating: /content/data/EDD-dataset/train/5/7013.png
#   inflating: /content/data/EDD-dataset/train/5/5837.png
#   inflating: /content/data/EDD-dataset/train/5/6682.png
#   inflating: /content/data/EDD-dataset/train/5/6680.png
#   inflating: /content/data/EDD-dataset/train/5/5835.png
#   inflating: /content/data/EDD-dataset/train/5/5809.png
#   inflating: /content/data/EDD-dataset/train/5/7005.png
#   inflating: /content/data/EDD-dataset/train/5/7011.png
#   inflating: /content/data/EDD-dataset/train/5/5799.png
#   inflating: /content/data/EDD-dataset/train/5/5955.png
#   inflating: /content/data/EDD-dataset/train/5/5969.png
#   inflating: /content/data/EDD-dataset/train/5/5996.png
#   inflating: /content/data/EDD-dataset/train/5/8083.png
#   inflating: /content/data/EDD-dataset/train/5/4875.png
#   inflating: /content/data/EDD-dataset/train/5/6737.png
#   inflating: /content/data/EDD-dataset/train/5/6723.png
#   inflating: /content/data/EDD-dataset/train/5/6722.png
#   inflating: /content/data/EDD-dataset/train/5/8069.png
#   inflating: /content/data/EDD-dataset/train/5/4874.png
#   inflating: /content/data/EDD-dataset/train/5/8082.png
#   inflating: /content/data/EDD-dataset/train/5/5997.png
#   inflating: /content/data/EDD-dataset/train/5/5983.png
#   inflating: /content/data/EDD-dataset/train/5/5968.png
#   inflating: /content/data/EDD-dataset/train/5/5954.png
#   inflating: /content/data/EDD-dataset/train/5/5798.png
#   inflating: /content/data/EDD-dataset/train/5/7010.png
#   inflating: /content/data/EDD-dataset/train/5/5808.png
#   inflating: /content/data/EDD-dataset/train/5/5834.png
#   inflating: /content/data/EDD-dataset/train/5/6681.png
#   inflating: /content/data/EDD-dataset/train/5/6685.png
#   inflating: /content/data/EDD-dataset/train/5/5617.png
#   inflating: /content/data/EDD-dataset/train/5/7014.png
#   inflating: /content/data/EDD-dataset/train/5/6450.png
#   inflating: /content/data/EDD-dataset/train/5/5978.png
#   inflating: /content/data/EDD-dataset/train/5/5950.png
#   inflating: /content/data/EDD-dataset/train/5/5788.png
#   inflating: /content/data/EDD-dataset/train/5/5777.png
#   inflating: /content/data/EDD-dataset/train/5/5987.png
#   inflating: /content/data/EDD-dataset/train/5/5993.png
#   inflating: /content/data/EDD-dataset/train/5/8086.png
#   inflating: /content/data/EDD-dataset/train/5/4870.png
#   inflating: /content/data/EDD-dataset/train/5/8079.png
#   inflating: /content/data/EDD-dataset/train/5/6726.png
#   inflating: /content/data/EDD-dataset/train/5/6727.png
#   inflating: /content/data/EDD-dataset/train/5/6733.png
#   inflating: /content/data/EDD-dataset/train/5/8078.png
#   inflating: /content/data/EDD-dataset/train/5/4871.png
#   inflating: /content/data/EDD-dataset/train/5/5992.png
#   inflating: /content/data/EDD-dataset/train/5/5986.png
#   inflating: /content/data/EDD-dataset/train/5/5776.png
#   inflating: /content/data/EDD-dataset/train/5/5789.png
#   inflating: /content/data/EDD-dataset/train/5/5951.png
#   inflating: /content/data/EDD-dataset/train/5/6451.png
#   inflating: /content/data/EDD-dataset/train/5/7015.png
#   inflating: /content/data/EDD-dataset/train/5/5616.png
#   inflating: /content/data/EDD-dataset/train/5/6690.png
#   inflating: /content/data/EDD-dataset/train/5/6684.png
#   inflating: /content/data/EDD-dataset/train/5/6686.png
#   inflating: /content/data/EDD-dataset/train/5/6679.png
#   inflating: /content/data/EDD-dataset/train/5/5833.png
#   inflating: /content/data/EDD-dataset/train/5/7017.png
#   inflating: /content/data/EDD-dataset/train/5/6453.png
#   inflating: /content/data/EDD-dataset/train/5/5953.png
#   inflating: /content/data/EDD-dataset/train/5/7188.png
#   inflating: /content/data/EDD-dataset/train/5/5990.png
#   inflating: /content/data/EDD-dataset/train/5/5984.png
#   inflating: /content/data/EDD-dataset/train/5/4873.png
#   inflating: /content/data/EDD-dataset/train/5/8085.png
#   inflating: /content/data/EDD-dataset/train/5/6719.png
#   inflating: /content/data/EDD-dataset/train/5/6725.png
#   inflating: /content/data/EDD-dataset/train/5/6730.png
#   inflating: /content/data/EDD-dataset/train/5/6724.png
#   inflating: /content/data/EDD-dataset/train/5/6718.png
#   inflating: /content/data/EDD-dataset/train/5/8084.png
#   inflating: /content/data/EDD-dataset/train/5/4872.png
#   inflating: /content/data/EDD-dataset/train/5/5985.png
#   inflating: /content/data/EDD-dataset/train/5/5991.png
#   inflating: /content/data/EDD-dataset/train/5/7189.png
#   inflating: /content/data/EDD-dataset/train/5/5952.png
#   inflating: /content/data/EDD-dataset/train/5/6452.png
#   inflating: /content/data/EDD-dataset/train/5/5615.png
#   inflating: /content/data/EDD-dataset/train/5/7016.png
#   inflating: /content/data/EDD-dataset/train/5/7200.png
#   inflating: /content/data/EDD-dataset/train/5/6678.png
#   inflating: /content/data/EDD-dataset/train/5/6687.png
#   inflating: /content/data/EDD-dataset/train/5/7273.png
#   inflating: /content/data/EDD-dataset/train/5/6390.png
#   inflating: /content/data/EDD-dataset/train/5/5841.png
#   inflating: /content/data/EDD-dataset/train/5/7924.png
#   inflating: /content/data/EDD-dataset/train/5/6384.png
#   inflating: /content/data/EDD-dataset/train/5/7918.png
#   inflating: /content/data/EDD-dataset/train/5/6353.png
#   inflating: /content/data/EDD-dataset/train/5/4236.png
#   inflating: /content/data/EDD-dataset/train/5/42.png
#   inflating: /content/data/EDD-dataset/train/5/6421.png
#   inflating: /content/data/EDD-dataset/train/5/6347.png
#   inflating: /content/data/EDD-dataset/train/5/5896.png
#   inflating: /content/data/EDD-dataset/train/5/5909.png
#   inflating: /content/data/EDD-dataset/train/5/6541.png
#   inflating: /content/data/EDD-dataset/train/5/3439.png
#   inflating: /content/data/EDD-dataset/train/5/5712.png
#   inflating: /content/data/EDD-dataset/train/5/6569.png
#   inflating: /content/data/EDD-dataset/train/5/7677.png
#   inflating: /content/data/EDD-dataset/train/5/6757.png
#   inflating: /content/data/EDD-dataset/train/5/8034.png
#   inflating: /content/data/EDD-dataset/train/5/8020.png
#   inflating: /content/data/EDD-dataset/train/5/8021.png
#   inflating: /content/data/EDD-dataset/train/5/8035.png
#   inflating: /content/data/EDD-dataset/train/5/6756.png
#   inflating: /content/data/EDD-dataset/train/5/7676.png
#   inflating: /content/data/EDD-dataset/train/5/6568.png
#   inflating: /content/data/EDD-dataset/train/5/3362.png
#   inflating: /content/data/EDD-dataset/train/5/5713.png
#   inflating: /content/data/EDD-dataset/train/5/3438.png
#   inflating: /content/data/EDD-dataset/train/5/5908.png
#   inflating: /content/data/EDD-dataset/train/5/43.png
#   inflating: /content/data/EDD-dataset/train/5/6420.png
#   inflating: /content/data/EDD-dataset/train/5/4237.png
#   inflating: /content/data/EDD-dataset/train/5/5897.png
#   inflating: /content/data/EDD-dataset/train/5/6346.png
#   inflating: /content/data/EDD-dataset/train/5/6352.png
#   inflating: /content/data/EDD-dataset/train/5/7919.png
#   inflating: /content/data/EDD-dataset/train/5/7925.png
#   inflating: /content/data/EDD-dataset/train/5/6385.png
#   inflating: /content/data/EDD-dataset/train/5/5840.png
#   inflating: /content/data/EDD-dataset/train/5/6391.png
#   inflating: /content/data/EDD-dataset/train/5/4779.png
#   inflating: /content/data/EDD-dataset/train/5/6387.png
#   inflating: /content/data/EDD-dataset/train/5/6393.png
#   inflating: /content/data/EDD-dataset/train/5/5842.png
#   inflating: /content/data/EDD-dataset/train/5/5895.png
#   inflating: /content/data/EDD-dataset/train/5/4235.png
#   inflating: /content/data/EDD-dataset/train/5/6422.png
#   inflating: /content/data/EDD-dataset/train/5/41.png
#   inflating: /content/data/EDD-dataset/train/5/6350.png
#   inflating: /content/data/EDD-dataset/train/5/6378.png
#   inflating: /content/data/EDD-dataset/train/5/6542.png
#   inflating: /content/data/EDD-dataset/train/5/4369.png
#   inflating: /content/data/EDD-dataset/train/5/5711.png
#   inflating: /content/data/EDD-dataset/train/5/3360.png
#   inflating: /content/data/EDD-dataset/train/5/6768.png
#   inflating: /content/data/EDD-dataset/train/5/8023.png
#   inflating: /content/data/EDD-dataset/train/5/8037.png
#   inflating: /content/data/EDD-dataset/train/5/8036.png
#   inflating: /content/data/EDD-dataset/train/5/6769.png
#   inflating: /content/data/EDD-dataset/train/5/8022.png
#   inflating: /content/data/EDD-dataset/train/5/6741.png
#   inflating: /content/data/EDD-dataset/train/5/4368.png
#   inflating: /content/data/EDD-dataset/train/5/3361.png
#   inflating: /content/data/EDD-dataset/train/5/5710.png
#   inflating: /content/data/EDD-dataset/train/5/6543.png
#   inflating: /content/data/EDD-dataset/train/5/6379.png
#   inflating: /content/data/EDD-dataset/train/5/6351.png
#   inflating: /content/data/EDD-dataset/train/5/5894.png
#   inflating: /content/data/EDD-dataset/train/5/6345.png
#   inflating: /content/data/EDD-dataset/train/5/6423.png
#   inflating: /content/data/EDD-dataset/train/5/40.png
#   inflating: /content/data/EDD-dataset/train/5/4234.png
#   inflating: /content/data/EDD-dataset/train/5/5843.png
#   inflating: /content/data/EDD-dataset/train/5/6392.png
#   inflating: /content/data/EDD-dataset/train/5/6386.png
#   inflating: /content/data/EDD-dataset/train/5/4778.png
#   inflating: /content/data/EDD-dataset/train/5/7275.png
#   inflating: /content/data/EDD-dataset/train/5/7922.png
#   inflating: /content/data/EDD-dataset/train/5/6382.png
#   inflating: /content/data/EDD-dataset/train/5/6396.png
#   inflating: /content/data/EDD-dataset/train/5/5847.png
#   inflating: /content/data/EDD-dataset/train/5/44.png
#   inflating: /content/data/EDD-dataset/train/5/6427.png
#   inflating: /content/data/EDD-dataset/train/5/6355.png
#   inflating: /content/data/EDD-dataset/train/5/50.png
#   inflating: /content/data/EDD-dataset/train/5/5714.png
#   inflating: /content/data/EDD-dataset/train/5/5728.png
#   inflating: /content/data/EDD-dataset/train/5/3359.png
#   inflating: /content/data/EDD-dataset/train/5/6547.png
#   inflating: /content/data/EDD-dataset/train/5/6976.png
#   inflating: /content/data/EDD-dataset/train/5/8026.png
#   inflating: /content/data/EDD-dataset/train/5/7329.png
#   inflating: /content/data/EDD-dataset/train/5/7328.png
#   inflating: /content/data/EDD-dataset/train/5/8027.png
#   inflating: /content/data/EDD-dataset/train/5/6977.png
#   inflating: /content/data/EDD-dataset/train/5/3358.png
#   inflating: /content/data/EDD-dataset/train/5/5729.png
#   inflating: /content/data/EDD-dataset/train/5/6546.png
#   inflating: /content/data/EDD-dataset/train/5/6552.png
#   inflating: /content/data/EDD-dataset/train/5/5715.png
#   inflating: /content/data/EDD-dataset/train/5/6354.png
#   inflating: /content/data/EDD-dataset/train/5/51.png
#   inflating: /content/data/EDD-dataset/train/5/45.png
#   inflating: /content/data/EDD-dataset/train/5/6426.png
#   inflating: /content/data/EDD-dataset/train/5/5846.png
#   inflating: /content/data/EDD-dataset/train/5/6397.png
#   inflating: /content/data/EDD-dataset/train/5/7923.png
#   inflating: /content/data/EDD-dataset/train/5/6383.png
#   inflating: /content/data/EDD-dataset/train/5/5852.png
#   inflating: /content/data/EDD-dataset/train/5/7274.png
#   inflating: /content/data/EDD-dataset/train/5/4780.png
#   inflating: /content/data/EDD-dataset/train/5/7276.png
#   inflating: /content/data/EDD-dataset/train/5/7909.png
#   inflating: /content/data/EDD-dataset/train/5/6395.png
#   inflating: /content/data/EDD-dataset/train/5/5844.png
#   inflating: /content/data/EDD-dataset/train/5/5688.png
#   inflating: /content/data/EDD-dataset/train/5/5850.png
#   inflating: /content/data/EDD-dataset/train/5/6381.png
#   inflating: /content/data/EDD-dataset/train/5/7921.png
#   inflating: /content/data/EDD-dataset/train/5/6418.png
#   inflating: /content/data/EDD-dataset/train/5/5893.png
#   inflating: /content/data/EDD-dataset/train/5/4233.png
#   inflating: /content/data/EDD-dataset/train/5/6424.png
#   inflating: /content/data/EDD-dataset/train/5/47.png
#   inflating: /content/data/EDD-dataset/train/5/3399.png
#   inflating: /content/data/EDD-dataset/train/5/5717.png
#   inflating: /content/data/EDD-dataset/train/5/6544.png
#   inflating: /content/data/EDD-dataset/train/5/6550.png
#   inflating: /content/data/EDD-dataset/train/5/6975.png
#   inflating: /content/data/EDD-dataset/train/5/8031.png
#   inflating: /content/data/EDD-dataset/train/5/6008.png
#   inflating: /content/data/EDD-dataset/train/5/8025.png
#   inflating: /content/data/EDD-dataset/train/5/8019.png
#   inflating: /content/data/EDD-dataset/train/5/8018.png
#   inflating: /content/data/EDD-dataset/train/5/8024.png
#   inflating: /content/data/EDD-dataset/train/5/6009.png
#   inflating: /content/data/EDD-dataset/train/5/8030.png
#   inflating: /content/data/EDD-dataset/train/5/6974.png
#   inflating: /content/data/EDD-dataset/train/5/6551.png
#   inflating: /content/data/EDD-dataset/train/5/6545.png
#   inflating: /content/data/EDD-dataset/train/5/3401.png
#   inflating: /content/data/EDD-dataset/train/5/5716.png
#   inflating: /content/data/EDD-dataset/train/5/3398.png
#   inflating: /content/data/EDD-dataset/train/5/5892.png
#   inflating: /content/data/EDD-dataset/train/5/6425.png
#   inflating: /content/data/EDD-dataset/train/5/46.png
#   inflating: /content/data/EDD-dataset/train/5/6419.png
#   inflating: /content/data/EDD-dataset/train/5/6380.png
#   inflating: /content/data/EDD-dataset/train/5/5851.png
#   inflating: /content/data/EDD-dataset/train/5/5689.png
#   inflating: /content/data/EDD-dataset/train/5/7920.png
#   inflating: /content/data/EDD-dataset/train/5/5845.png
#   inflating: /content/data/EDD-dataset/train/5/6394.png
#   inflating: /content/data/EDD-dataset/train/5/7908.png
#   inflating: /content/data/EDD-dataset/train/5/4024.png
#   inflating: /content/data/EDD-dataset/train/5/7277.png

# %%
# Might be a good idea to make the image in grayscale and make them smaller (check here: https://pytorch.org/vision/stable/transforms.html)
edd_train = CustomImageDataset(edd_train_data_csv, edd_train_data)

print(len(edd_train))
sample = edd_train[0]
print(type(sample["image"]))
print(sample["image"].shape)

# print(edd_train[0])
# Out:
# 6386
# <class 'torch.Tensor'>
# torch.Size([3, 500, 500])

# %%
figure = plt.figure(figsize=(8, 8))
cols, rows = 3, 3
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(edd_train), size=(1,)).item() # Get rnd_id
    sample = edd_train[sample_idx] # index dataset (gets you the img and label - index)
    img, label = sample["image"], sample["label"]
    figure.add_subplot(rows, cols, i)
    plt.title(img.shape)
    plt.axis("off")
#     plt.imshow(img.squeeze(), cmap="gray") # if the image is grayscale
    plt.imshow(img.permute(1,2,0)) # put channel as the last dimension
plt.show()

# %% [markdown]
# ## Preparing your data for training with DataLoaders ##
# The Dataset retrieves our dataset’s features and labels one sample at a time. While training a model, we typically want to pass samples in “minibatches”, reshuffle the data at every epoch to reduce model overfitting, and use Python’s multiprocessing to speed up data retrieval.
#
# DataLoader is an iterable that abstracts this complexity for us in an easy API.

# %%
from torch.utils.data import DataLoader

train_dataloader = DataLoader(training_data, batch_size=64, shuffle=True)
test_dataloader = DataLoader(test_data, batch_size=64, shuffle=True)

# %%
# Display image and label.
train_features, train_labels = next(iter(train_dataloader))
# [64, 1, 28, 28] -- 64 batch size, 1 channels, 28 width, 28 height
print(f"Feature batch shape: {train_features.size()}")
print(f"Labels batch shape: {train_labels.size()}")

img = train_features[0].squeeze()
label = train_labels[0]
plt.imshow(img, cmap="gray")
plt.show()
print(f"Label: {label}")
# Out:
# Feature batch shape: torch.Size([64, 1, 28, 28])
# Labels batch shape: torch.Size([64])
# Label: 1

# %% [markdown]
# ## TRANSFORMS ##
# Data does not always come in its final processed form that is required for training machine learning algorithms. We use transforms to perform some manipulation of the data and make it suitable for training.
#
# All TorchVision datasets have two parameters -__transform__ to modify the features and __target_transform__ to modify the labels - that accept callables containing the transformation logic. The torchvision.transforms module offers several commonly-used transforms out of the box.
#
# The FashionMNIST features are in PIL Image format, and the labels are integers. For training, we need the features as normalized tensors, and the labels as one-hot encoded tensors. To make these transformations, we use ToTensor and Lambda.

# %%
from torchvision import datasets
from torchvision.transforms import ToTensor, Lambda

ds = datasets.FashionMNIST(
    root=data_path,
    train=True,
    download=True,
    transform=ToTensor(), # Converts the image to a tensor
    target_transform=Lambda(lambda y: torch.zeros(10, dtype=torch.float).scatter_(0, torch.tensor(y), value=1))
)


#Lambda transforms apply any user-defined lambda function. Here, we define a function to turn the integer into a one-hot encoded tensor. 
# It first creates a zero tensor of size 10 (the number of labels in our dataset) and 
# calls scatter_ which assigns a value=1 on the index as given by the label y.
